# %% [markdown]
# <a href="https://colab.research.google.com/github/septianwijaya45/PVCK_Modul_1-2/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import cv2 as cv
from google.colab.patches import cv2_imshow
from skimage import io
from skimage import transform
from PIL import Image
import matplotlib.pylab as plt

# %%
urls = ["https://iiif.lib.ncsu.edu/iiif/0052574/full/800,/0/default.jpg",
        "https://iiif.lib.ncsu.edu/iiif/0016007/full/800,/0/default.jpg",
        "https://placekitten.com/800/571"]

for url in urls:
  image = io.imread(url)
  image = cv.resize(image, (0,0), fx=0.5, fy=0.5)
  image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
  final_frame = cv.hconcat((image, image_2))
  cv2_imshow(final_frame)
  print('n')
# Out:
# <PIL.Image.Image image mode=RGB size=800x276 at 0x7F1190597F50>
# n
# <PIL.Image.Image image mode=RGB size=800x286 at 0x7F119059F5D0>
# n
# <PIL.Image.Image image mode=RGB size=800x286 at 0x7F11906053D0>
# n

# %%
tinggi = image_2.shape[0]
lebar = image_2.shape[1]
print("resolusi image: tinggi x lebar = ", tinggi, " x ", lebar)
cv2_imshow(image_2)
# Out:
# resolusi image: tinggi x lebar =  286  x  400
# <PIL.Image.Image image mode=RGB size=400x286 at 0x7F118A27F590>

# %%
image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
image_3 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
for y in range (lebar):
  image_3[int((tinggi)/2), y] = [255,255,255]

final_frame = cv.hconcat((image_2, image_3))
cv2_imshow(final_frame)
# Out:
# <PIL.Image.Image image mode=RGB size=800x286 at 0x7F118A1B89D0>

# %% [markdown]
# 1. Jelaskan, mengapa pada modul praktikum ini eksekusi kode Python dilakukan
# menggunakan Google Colab?
#    Jawab:
#    Karena Google Colab memiliki modul python yang tidak perlu di install kembali serta mudah digunakan saat berkolaborasi
#
# 2. Jelaskan mengenai kegunaan setiap library pada praktikum langkah ke delapan?
# Apakah semua library tersebut harus digunakan dalam praktikum sesi ini?
#   Jawab:
#   a. Numpy: salah satu library yang disediakan oleh Python dalam memudahkan operasi komputasi tipe data numerik
#   b. pandas: sebuah library berlisensi BSD dan open source yang menyediakan struktur data dan analisis data yang mudah digunakan dan berkinerja tinggi
#   c. cv2: sebuah library (perpustakaan) yang digunakan untuk mengolah gambar dan video
#   d. skimage: sebuah modul yang berupa kumpulan algoritma untuk pemrosesan gambar.
#   e. PIL:  library open-source tambahan untuk Python yang fungsi utamanya adalah memanipulasi file gambar
#   f. Matplotlib: pustaka visualisasi data multiplatform yang dibangun di atas array NumPy
#
# 3. Apa kegunaan kode program tersebut?dan apa pengaruhnya jika tidak dilakukan?
#   Jawab:
#   kode program tersebut untuk ukuran gambar berarti mengubah dimensinya, baik itu lebar saja, tinggi saja atau mengubah keduanya. Selain itu, rasio aspek gambar asli dapat dipertahankan dalam gambar yang diubah ukurannya. Jika tidak menggunakan kode tersebut tidak dipermasalahkan tetapi ukuran gambar sesuai dengan ukuran asli
#
# 4. Apakah kegunaan kode [255,255,255] ? Jelaskan!
#   Jawab:
#   Kegunaan kode tersebut adalah untuk menentukan warna garis yang akan digunakan
#
# 5. Jelaskan keterkaitan antara pixel dan juga resolusi gambar yang tinggi ataupun rendah!
#   Jawab:
#   Hubungan antara pixel dengan resolusi gambar sangat dekat. Jika pixel semakin banyak maka resolusi gambar akan tinggi dan terlihat halus. Sebaliknya, jika pixel semakin sedikit, maka resolusi gambar akan rendah dan terlihat kasar
